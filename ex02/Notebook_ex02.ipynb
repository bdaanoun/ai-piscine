# %%
sentence = "Remove, this from .? the sentence !!!! !\"#&'()*+,-./:;<=>_"

puncts = "!\"#$%&'()\*+,-./:;<=>?@[\]^\_`{|}~"

table = str.maketrans('', '', puncts)
cleaned_sent = sentence.translate(table)

print(cleaned_sent)
# Out:
# Remove, this from .? the sentence !!!! !"#&'()*+,-./:;<=>_
# Remove this from  the sentence

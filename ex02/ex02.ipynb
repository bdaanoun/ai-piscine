# %%
import pandas as pd

df = pd.DataFrame({
    'name':['christopher','marion','maria','mia','clement','randy','remi'],
    'age':[70,30,22,19,45,33,20],
    'gender':['M','F','F','F','M','M','M'],
    'state':['california','dc','california','dc','california','new york','porto'],
    'num_children':[4,2,1,0,3,1,0],
    'num_pets':[5,1,0,2,2,2,3]
})


df.plot(title="Scatter plot: Number of childeren and age", x="age", y="num_children", kind="scatter")
# Out:
# <Axes: title={'center': 'Scatter plot: Number of childeren and age'}, xlabel='age', ylabel='num_children'>

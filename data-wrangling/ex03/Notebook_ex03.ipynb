# %%
import pandas as pd
import numpy as np

# Merge MultiIndex

# generate days
all_dates = pd.date_range('2021-01-01', '2021-12-15')
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index_alt = pd.MultiIndex.from_product([all_dates, tickers], names=['Date', 'Ticker'])
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 3),
                        columns=['Open','Close','Close_Adjusted'])

alternative_data = pd.DataFrame(index=index_alt,
                                data=np.random.randn(len(index_alt), 2),
                                columns=['Twitter','Reddit'])


merged = market_data.merge(
    alternative_data,
    how='left',
    left_index=True,
    right_index=True
)

filled_0 = merged.fillna(0)
merged.index = pd.Index(list(merged.index))

print(merged.shape)
print(merged.head().to_markdown())



filled_0.sum().sum() == merged.sum().sum()
# Out:
# (1305, 5)
# |                                            |      Open |     Close |   Close_Adjusted |   Twitter |    Reddit |
# |:-------------------------------------------|----------:|----------:|-----------------:|----------:|----------:|
# | (Timestamp('2021-01-01 00:00:00'), 'AAPL') |  1.29257  |  1.31228  |       -0.329683  |  1.21174  |  0.722555 |
# | (Timestamp('2021-01-01 00:00:00'), 'FB')   |  1.29761  |  0.880898 |       -0.0875488 |  1.69777  | -0.198856 |
# | (Timestamp('2021-01-01 00:00:00'), 'GE')   | -0.448659 |  0.63312  |        0.308785  |  0.732831 |  0.473844 |
# | (Timestamp('2021-01-01 00:00:00'), 'AMZN') |  1.43917  | -2.44576  |        1.55256   | -1.79129  |  0.217357 |
# | (Timestamp('2021-01-01 00:00:00'), 'DAI')  |  1.01666  | -0.849117 |       -0.34543   | -0.928164 | -0.271326 |
# np.True_

# %%
# Unstack
import pandas as pd
import numpy as np


business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Prediction'])


unstacked_df = market_data.unstack()
print(unstacked_df.head(3).to_markdown())
# Out:
# | Date                |   ('Prediction', 'AAPL') |   ('Prediction', 'AMZN') |   ('Prediction', 'DAI') |   ('Prediction', 'FB') |   ('Prediction', 'GE') |
# |:--------------------|-------------------------:|-------------------------:|------------------------:|-----------------------:|-----------------------:|
# | 2021-01-01 00:00:00 |                -0.781849 |                -0.124862 |                0.521513 |               0.822465 |              -2.1759   |
# | 2021-01-04 00:00:00 |                 1.96588  |                 0.393358 |                0.348541 |               0.210434 |              -1.5931   |
# | 2021-01-05 00:00:00 |                -0.120325 |                 0.671803 |               -1.94499  |               1.51639  |               0.536789 |

# %%
unstacked_df.plot(title="time Series")
# Out:
# <Axes: title={'center': 'time Series'}, xlabel='Date'>

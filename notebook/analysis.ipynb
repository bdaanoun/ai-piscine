# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from scripts.memory_reducer import memory_reducer

# load data
prices = memory_reducer("../data/stock_prices.csv")
sp500 = memory_reducer("../data/sp500.csv")

# print(prices.shape)
# print(prices.head(3))
# print()
# print(sp500.shape)
# print(sp500.head(3))

prices = prices.set_index("Date")
prices = prices.resample("ME").last()
prices = prices.sort_index()

print(prices.shape)
prices.head(3)
# Out:
# (169, 543)
#                     A         AA      AAPL  ABBV        ABC        ABT  \
# Date
# 2000-12-31  36.730354  25.950483  1.006463   NaN  11.438262  38.794544
# 2001-01-31  36.596180  28.576517  1.462347   NaN  10.833507  35.999401
# 2001-02-28  24.151464  27.814268  1.234405   NaN  12.167593  39.313656
#
#                   ACE        ACI  ACN        ACT  ...        XOM       XRAY  \
# Date                                              ...
# 2000-12-31  31.431623   6.057003  NaN  51.189999  ...  31.512054  12.280495
# 2001-01-31  27.402687   6.177114  NaN  52.060001  ...  30.500799  10.846253
# 2001-02-28  27.106441  10.102155  NaN  55.500000  ...  29.453793  11.809737
#
#                  XRX  XYL       YHOO       YUM       ZION    ZLC  ZMH  ZNGA
# Date
# 2000-12-31  3.956393  NaN  15.030000  6.963493  51.146896  14.53  NaN   NaN
# 2001-01-31  6.996479  NaN  18.655001  7.600759  45.773357  18.65  NaN   NaN
# 2001-02-28  5.215245  NaN  11.905000  8.124076  47.212597  15.73  NaN   NaN
#
# [3 rows x 543 columns]

# %%
def plot_avg_price(prices, plot=False):
    avg_price = prices.mean(axis=1)  # mean across all companies per month
    
    plt.figure(figsize=(12, 5))
    plt.plot(avg_price.index, avg_price.values)
    plt.title("Average Stock Price Over Time")
    plt.xlabel("Date")
    plt.ylabel("Average Price ($)")
    plt.tight_layout()
    plt.savefig("../results/plots/avg_price.png")
    
    if plot:
        plt.show()
    plt.close()

plot_avg_price(prices)

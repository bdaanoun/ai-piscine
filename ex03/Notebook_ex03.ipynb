# %%
# Exercise 3: Multi asset returns

import pandas as pd
import numpy as np

business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Price'])

daily_returns = market_data.pivot_table(index="Date", values="Price", columns="Ticker").pct_change()


print(daily_returns.head().to_markdown())

print(daily_returns.shape)
# Out:
# | Date                |       AAPL |       AMZN |        DAI |          FB |         GE |
# |:--------------------|-----------:|-----------:|-----------:|------------:|-----------:|
# | 2021-01-01 00:00:00 | nan        | nan        | nan        | nan         | nan        |
# | 2021-01-04 00:00:00 |   0.409609 |   0.297785 |  -1.48779  |  -1.64103   |  -0.415811 |
# | 2021-01-05 00:00:00 |  -0.290409 |   0.578065 |   0.373684 |   0.0438147 |   0.897248 |
# | 2021-01-06 00:00:00 |  -0.712803 |  -1.2642   |  -2.72613  |  -0.971005  |  -0.464854 |
# | 2021-01-07 00:00:00 |  -0.260161 |   1.04668  |  -1.23524  |  -0.0667318 |  -1.65086  |
# (261, 5)

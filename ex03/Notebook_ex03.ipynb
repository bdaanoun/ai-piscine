# %%
# imports
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# data
housing = fetch_california_housing()
X, y = housing['data'], housing['target']
# split data train test
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.1,
                                                    shuffle=True,
                                                    random_state=43)

rf_model = RandomForestRegressor(random_state=42)
params = {'n_estimators':[10, 50, 75],
            'max_depth':[4, 7, 10]}
gs = GridSearchCV(estimator=rf_model, param_grid=params, n_jobs=-1, cv=5, scoring="neg_mean_squared_error")
gs.fit(X_train, y_train)

print("best estimator: ", gs.best_estimator_)
print("score: ",gs.best_score_)
print("best params: ",gs.best_params_)
print("result: ", gs.cv_results_)

# compute the score
test_score = gs.score(X_test, y_test)
print("test score:", test_score)
# Out:
# best estimator:  RandomForestRegressor(max_depth=10, n_estimators=75, random_state=42)
# score:  -0.29177799247453484
# best params:  {'max_depth': 10, 'n_estimators': 75}
# result:  {'mean_fit_time': array([0.31449842, 1.64634371, 2.36623054, 0.63078995, 2.68330092,
#        3.95916753, 0.74655252, 3.64307933, 4.59906049]), 'std_fit_time': array([0.01266058, 0.04826808, 0.07096819, 0.13034792, 0.02960885,
#        0.09597854, 0.04316484, 0.10801402, 0.25605404]), 'mean_score_time': array([0.00224819, 0.00748949, 0.0107645 , 0.00309381, 0.01266813,
#        0.01717844, 0.00435786, 0.01575489, 0.01954794]), 'std_score_time': array([4.05803830e-05, 2.28596619e-04, 3.82401538e-04, 3.76449573e-05,
#        6.30213450e-04, 1.52483617e-03, 3.22024144e-04, 1.46228651e-03,
#        6.84559505e-04]), 'param_max_depth': masked_array(data=[4, 4, 4, 7, 7, 7, 10, 10, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False],
#        fill_value=999999), 'param_n_estimators': masked_array(data=[10, 50, 75, 10, 50, 75, 10, 50, 75],
#              mask=[False, False, False, False, False, False, False, False,
#                    False],
#        fill_value=999999), 'params': [{'max_depth': 4, 'n_estimators': 10}, {'max_depth': 4, 'n_estimators': 50}, {'max_depth': 4, 'n_estimators': 75}, {'max_depth': 7, 'n_estimators': 10}, {'max_depth': 7, 'n_estimators': 50}, {'max_depth': 7, 'n_estimators': 75}, {'max_depth': 10, 'n_estimators': 10}, {'max_depth': 10, 'n_estimators': 50}, {'max_depth': 10, 'n_estimators': 75}], 'split0_test_score': array([-0.48928389, -0.48686851, -0.48847196, -0.33870797, -0.33509965,
#        -0.33675746, -0.27547947, -0.26273623, -0.2627877 ]), 'split1_test_score': array([-0.53598641, -0.526539  , -0.52661725, -0.38077699, -0.36708689,
#        -0.36731639, -0.29985088, -0.2888477 , -0.29012937]), 'split2_test_score': array([-0.52966444, -0.52713936, -0.52432726, -0.38714064, -0.37923336,
#        -0.37675931, -0.314921  , -0.3026098 , -0.30086678]), 'split3_test_score': array([-0.51013562, -0.50801982, -0.50788552, -0.37215875, -0.37172092,
#        -0.37282094, -0.31810043, -0.30714887, -0.30569013]), 'split4_test_score': array([-0.5344391 , -0.52794389, -0.52835952, -0.38159668, -0.37341183,
#        -0.3719778 , -0.31652169, -0.30263162, -0.29941599]), 'mean_test_score': array([-0.51990189, -0.51530211, -0.5151323 , -0.37207621, -0.36531053,
#        -0.36512638, -0.30497469, -0.29279484, -0.29177799]), 'std_test_score': array([0.01787843, 0.01604808, 0.01519671, 0.0173593 , 0.01559758,
#        0.01449873, 0.01612928, 0.0162372 , 0.01534697]), 'rank_test_score': array([9, 8, 7, 6, 5, 4, 3, 2, 1], dtype=int32)}
# test score: -0.2755958765583682

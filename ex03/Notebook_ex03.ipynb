# %%
import pandas as pd
import numpy as np

# Merge MultiIndex

# generate days
all_dates = pd.date_range('2021-01-01', '2021-12-15')
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index_alt = pd.MultiIndex.from_product([all_dates, tickers], names=['Date', 'Ticker'])
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 3),
                        columns=['Open','Close','Close_Adjusted'])

alternative_data = pd.DataFrame(index=index_alt,
                                data=np.random.randn(len(index_alt), 2),
                                columns=['Twitter','Reddit'])

market_data.merge(alternative_data, how='left', left_index=True, right_index=True)
# Out:
#                        Open     Close  Close_Adjusted   Twitter    Reddit
# Date       Ticker
# 2021-01-01 AAPL    0.871435 -1.905476       -0.286040  0.349461 -0.239060
#            FB      0.465439 -0.435839       -2.969300 -0.191415  0.767984
#            GE     -1.270397 -1.126023        0.019338 -0.877300  0.181087
#            AMZN    0.230383 -0.163216       -0.268224  0.591009 -1.067237
#            DAI    -1.452303  1.537711        0.637234  0.904648 -1.065609
# ...                     ...       ...             ...       ...       ...
# 2021-12-31 AAPL    0.584045 -0.581608       -0.986834       NaN       NaN
#            FB     -0.492733 -1.300031        0.389348       NaN       NaN
#            GE     -1.584514 -0.579369        2.014257       NaN       NaN
#            AMZN   -1.355902  1.881134        0.763460       NaN       NaN
#            DAI    -0.907930 -0.478128        1.125114       NaN       NaN
#
# [1305 rows x 5 columns]

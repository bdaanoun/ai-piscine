# %%
# Multi classification example
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelBinarizer

from keras.models import Sequential
from keras.layers import Dense

data = load_iris(as_frame=True)
X = data.data
y = data.target

X_train, X_test, y_train, y_test =  train_test_split(X, y, test_size=0.2, random_state=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

lb = LabelBinarizer()
print(y.unique())
y_oneHot = lb.fit_transform(y)

y_train_onehot = lb.fit_transform(y_train)
y_test_onehot = lb.transform(y_test)

model = Sequential()
model.add(Dense(64, input_dim=4, activation="sigmoid"))
model.add(Dense(32, activation="sigmoid"))
model.add(Dense(3, activation="softmax"))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

model.fit(X_train_scaled, y_train_onehot, epochs=50, batch_size=8, validation_data=(X_test_scaled, y_test_onehot))
y_train_onehot[:10]
# Out:
# [0 1 2]
# Epoch 1/50
# /home/bdaanoun/keras-2/kera2/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3833 - loss: 1.1071 - val_accuracy: 0.3000 - val_loss: 1.0934
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5000 - loss: 1.0646 - val_accuracy: 0.3667 - val_loss: 1.0833
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6833 - loss: 1.0322 - val_accuracy: 0.5667 - val_loss: 1.0407
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6833 - loss: 1.0061 - val_accuracy: 0.5667 - val_loss: 0.9994
# Epoch 5/50
# ...

# %%
loss, acc = model.evaluate(X_test_scaled,y_test_onehot)
print("loss",loss)
print("acc",acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9667 - loss: 0.1844
# loss 0.18444980680942535
# acc 0.9666666388511658
